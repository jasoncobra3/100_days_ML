# %% [markdown]
# # Data

# %% [markdown]
# ![Screenshot%20%28503%29.png](attachment:Screenshot%20%28503%29.png)

# %% [markdown]
# ### From below you can see that , we are implementing a single Decision tree and Its overfit as usual on training data with accuracy of 92%.

# %% [markdown]
# ![Screenshot%20%28504%29.png](attachment:Screenshot%20%28504%29.png)

# %% [markdown]
# ### From below you can see that to reduce overfitting of Single Decision tree we are implementing Baggging regressor with decision regressor as base model such that we get a more accuracy as 95% on data and it reduces the overfitting.

# %% [markdown]
# ![Screenshot%20%28508%29.png](attachment:Screenshot%20%28508%29.png)

# %% [markdown]
# # Conclude
