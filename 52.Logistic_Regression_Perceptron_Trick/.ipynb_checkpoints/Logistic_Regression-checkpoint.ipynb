# %% [markdown]
# # Logistic_Regression

# %% [markdown]
# ### Two Perspectives Of Logitic Regression<br>1.Geometric <br> 2.Probablity

# %% [markdown]
# ## Requirements For Logistic Regression

# %% [markdown]
# ### 1.Data Must Be Linearly Separable

# %% [markdown]
# ### for 2D it must be separate by Line & for higher dimension data must be separate by hyperplane

# %% [markdown]
# ![Screenshot%20%28405%29.png](attachment:Screenshot%20%28405%29.png)

# %% [markdown]
# ![Screenshot%20%28406%29.png](attachment:Screenshot%20%28406%29.png)

# %% [markdown]
# # <br>

# %% [markdown]
# ### Logistic Regression Cannot be apply on Non linear Data

# %% [markdown]
# # <hr>

# %% [markdown]
# # Perceptron Trick

# %% [markdown]
# ### Equation of ine in Logistic Regression is

# %% [markdown]
# ![Screenshot%20%28407%29.png](attachment:Screenshot%20%28407%29.png)

# %% [markdown]
# #### 1.For Perceptron trick we run a loop for 1000 eochs(generally)<br>2.Select a random data points

# %% [markdown]
# # <hr>

# %% [markdown]
# ## How to Label Regions..?

# %% [markdown]
# ## 1.For line=0

# %% [markdown]
# ![Screenshot%20%28409%29.png](attachment:Screenshot%20%28409%29.png)

# %% [markdown]
# ## For Positive Region <br> equation of line >0

# %% [markdown]
# ![Screenshot%20%28410%29.png](attachment:Screenshot%20%28410%29.png)

# %% [markdown]
# ## For Negative Region <br> Equation of line < 0

# %% [markdown]
# ![Screenshot%20%28408%29.png](attachment:Screenshot%20%28408%29.png)

# %% [markdown]
# # <hr>

# %% [markdown]
# # TRANSFORMATIONS for Line

# %% [markdown]
# ## 1. By making Changes in C , the Line moves parallel to the current position <br>

# %% [markdown]
# ![Screenshot%20%28412%29.png](attachment:Screenshot%20%28412%29.png)

# %% [markdown]
# ### From above graph you can see that , Line moves parallel from its current position

# %% [markdown]
# ## 1.As the Value of C increases line move Downwards (for c=10)<br> 2.As the value of C Decreases line move Upwards (for c=1)

# %% [markdown]
# # <br>

# %% [markdown]
# # 2.By making changes in A

# %% [markdown]
# ![Screenshot%20%28413%29.png](attachment:Screenshot%20%28413%29.png)

# %% [markdown]
# ## From above We can see that By making Changes in A  , We can change the intercept of line along X axis , by keeping the Y intersection as it is without any change.

# %% [markdown]
# # <br>

# %% [markdown]
# # 3.By making changes in B

# %% [markdown]
# ![Screenshot%20%28414%29.png](attachment:Screenshot%20%28414%29.png)

# %% [markdown]
# ## From above We can see that By making Changes in B  , We can change the intercept of line along Y axis , by keeping the X intersection as it is without any change.

# %% [markdown]
# ## 1. When we want to move Line in Positive region we Perform Subtraction<br> 2.When we want to move Line in Negative region we Perform Addition

# %% [markdown]
# ### Observe the below Grpahs

# %% [markdown]
# ![Screenshot%20%28415%29.png](attachment:Screenshot%20%28415%29.png)

# %% [markdown]
# ### 1.Moving point to +ve Region

# %% [markdown]
# ![Screenshot%20%28416%29.png](attachment:Screenshot%20%28416%29.png)

# %% [markdown]
# ![Screenshot%20%28417%29.png](attachment:Screenshot%20%28417%29.png)

# %% [markdown]
# ### from above we moved a point to positive region of Line

# %% [markdown]
# ![Screenshot%20%28418%29.png](attachment:Screenshot%20%28418%29.png)

# %% [markdown]
# # ALGORITHM

# %% [markdown]
# ![WhatsApp%20Image%202024-02-07%20at%206.05.11%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-07%20at%206.05.11%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-07%20at%206.05.12%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-07%20at%206.05.12%20PM.jpeg)

# %% [markdown]
# # Conclude
