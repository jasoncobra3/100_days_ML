# %% [markdown]
# # Hyperparameters
# ## class sklearn.ensemble.BaggingClassifier(estimator=None, n_estimators=10, *, max_samples=1.0, max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, warm_start=False, n_jobs=None, random_state=None, verbose=0)

# %% [markdown]
# ## 1.Estimator=base_Model<br>Estimator means base model we are going to use for bagging its by default value is None

# %% [markdown]
# ## 2.n_estimators=10<br>its by default value is 10, we can pass n number in these parameter , such that it will decide how many times does the estimator will pass to bagging technique

# %% [markdown]
# # 3.bootstrap=True<br>it Will denote that, choose sample of data will contain the repeated row in it.

# %% [markdown]
# ## 4.oob_score=False<br>Score of the training dataset obtained using an out-of-bag estimate. This attribute exists only when oob_score is Tru

# %% [markdown]
# ## 5.Max_featues=1.0<br> it will decide the number of column to be get selected when we are using technique like random_subspaces or random_patches

# %% [markdown]
# ## 6.Max_sample=1.0<br>it will use to select maximum number of rows in bagging and pasting technique for replace

# %% [markdown]
# ## 7.verbose=int, default=0<br>Controls the verbosity when fitting and predicting

# %% [markdown]
# # <br>

# %% [markdown]
# ### when we use single Decision tree on data , you can see that, model overfits by separting each poin in the data and creating rough curves for classification

# %% [markdown]
# ![Screenshot%20%28496%29.png](attachment:Screenshot%20%28496%29.png)

# %% [markdown]
# ## You can see that after using Bagging with decision tree as estimator the performance improves by classifying data points with smooth curve

# %% [markdown]
# ![Screenshot%20%28492%29.png](attachment:Screenshot%20%28492%29.png)

# %% [markdown]
# # Similary for KNN you can see that below graphs.

# %% [markdown]
# ## When single KNN is used

# %% [markdown]
# ![Screenshot%20%28493%29.png](attachment:Screenshot%20%28493%29.png)

# %% [markdown]
# ## When KNN is used as estimator for Bagging

# %% [markdown]
# ![Screenshot%20%28494%29.png](attachment:Screenshot%20%28494%29.png)

# %% [markdown]
# # <br>

# %% [markdown]
# ## For Single SVM V/s SVM as Estimator in Bagging

# %% [markdown]
# ![Screenshot%20%28495%29.png](attachment:Screenshot%20%28495%29.png)

# %% [markdown]
# # <hr>

# %% [markdown]
# # Data

# %% [markdown]
# ![Screenshot%20%28497%29.png](attachment:Screenshot%20%28497%29.png)

# %% [markdown]
# # Random Subspaces`

# %% [markdown]
# ![Screenshot%20%28498%29.png](attachment:Screenshot%20%28498%29.png)

# %% [markdown]
# ![Screenshot%20%28501%29.png](attachment:Screenshot%20%28501%29.png)

# %% [markdown]
# ## From above you can understand that, Random_subspaces or random_patches may use when we have large number of columns in our data

# %% [markdown]
# # Random_patches

# %% [markdown]
# ![Screenshot%20%28502%29.png](attachment:Screenshot%20%28502%29.png)

# %% [markdown]
# # Conclude
