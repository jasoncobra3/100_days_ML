# %% [markdown]
# ![WhatsApp Image 2024-04-01 at 1.37.32 AM (2).jpeg](attachment:155c0cfb-e80a-4627-9173-1f68d6185d86.jpeg)

# %% [markdown]
# ![WhatsApp Image 2024-04-01 at 1.37.33 AM.jpeg](attachment:90917aa3-d176-416e-a626-ee619fe607ee.jpeg)

# %% [markdown]
# ![Screenshot (580).png](attachment:7b107337-ffac-42e8-a25f-4b804f750a20.png)

# %% [markdown]
# ![Screenshot (581).png](attachment:540916d1-97df-4cb8-b8d1-5f1b81f3968d.png)

# %% [markdown]
# ![WhatsApp Image 2024-04-01 at 1.37.33 AM (1).jpeg](attachment:af53e3ef-30b6-4c10-b0c8-e8b847dc34bb.jpeg)

# %% [markdown]
# # <hr>

# %% [markdown]
# # DBSCAN Algorithm

# %% [markdown]
# ![Screenshot (582).png](attachment:ad89dcd4-35fe-4581-8f1c-2ff0577a63f9.png)

# %% [markdown]
# # Advantages of DBSCAN

# %% [markdown]
# ![Screenshot (583).png](attachment:83c0d19f-0ea0-47bb-a19d-1e97727093a6.png)

# %% [markdown]
# # Limitations of DBSCAN

# %% [markdown]
# ![Screenshot (584).png](attachment:fad42851-3b7e-40cf-bb76-55116d0c086d.png)

# %% [markdown]
# # Conclude
