# %% [markdown]
# ## ElasticNet is combination of Ridge Regression + Lasso Regression

# %% [markdown]
# ### We use Ridge Regression when all columns in the Data are important and Dependent on Output <br> While in case of Lasso Regression we use it when we want to perform Feature Selection For the data.

# %% [markdown]
# ### Formula for Elasticnet Regression:-

# %% [markdown]
# ![Screenshot%20%28392%29.png](attachment:Screenshot%20%28392%29.png)

# %% [markdown]
# # <hr>

# %% [markdown]
# # Code

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y=load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# #### 1.Linear Regression

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
print("Accuracy Score",r2_score(y_test,y_pred))
# Out:
# Accuracy Score 0.4399338661568969

# %% [markdown]
# #### 2.Ridge Regression

# %%
reg=Ridge(alpha=0.1)
reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
print("Accuracy Score",r2_score(y_test,y_pred))
# Out:
# Accuracy Score 0.4519949419719548

# %% [markdown]
# #### 3.Lasso Regression

# %%
reg=Lasso(alpha=0.01)
reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
print("Accuracy Score",r2_score(y_test,y_pred))
# Out:
# Accuracy Score 0.44111855963110613

# %% [markdown]
# #### 4.ElasticNet Regression

# %%
reg=ElasticNet(alpha=0.005,l1_ratio=0.9)
reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
print("Accuracy Score",r2_score(y_test,y_pred))
# Out:
# Accuracy Score 0.4531474541554823

# %% [markdown]
# # <hr>

# %% [markdown]
# ### 1.We use ElasticNet Regression when we don't Know Which Regression technique is Used from Both(Ridge,Lasso)<br>2.Also When Multicollinearity is present in the Data then we use , ElasticNet Regression

# %% [markdown]
# # <hr>

# %% [markdown]
# ## We are using ElasticNet() clas of sklearn , in which alpha and L1_ration is pass , L1_ratio decides whether which regression weightage needs to implement more ,<br>[In above L1_ratio=0.9 , which means we are impementing 90%Ridge Regression and 10% Lasso Regression in above Example ]<br> By Default value of alpha is 0.5 & L1_ratio is 1 , which means 0.5 Ridge Regression and 0.5 Lasso Regression

# %% [markdown]
# ### We Can implement the ElasticNet Regression By using SGDRegressor Class of Sklearn also.

# %% [markdown]
# # <hr>

# %% [markdown]
# # Conclude
