# %% [markdown]
# ![Screenshot%20%28429%29.png](attachment:Screenshot%20%28429%29.png)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-11%20at%205.39.21%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-11%20at%205.39.21%20PM.jpeg)

# %% [markdown]
# ![Screenshot%20%28430%29.png](attachment:Screenshot%20%28430%29.png)

# %% [markdown]
# ## Above Is the Graph for Derivative of Sigmoid Function 👆🏻👆🏻

# %% [markdown]
# # <br>

# %% [markdown]
# # Conclude
