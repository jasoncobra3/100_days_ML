# %% [markdown]
# # Developing Linear Regression From Scratch

# %% [markdown]
# ![Screenshot%20%28319%29.png](attachment:Screenshot%20%28319%29.png)

# %% [markdown]
# ### We can find formula using Two ways <br> 1.Closed Form Solution (Uses Simple arithmatic Operations excluding Deriatives and Integration)<br>2.Non Closed Form Solution

# %% [markdown]
# # OLS stands for Ordinary Least Square , this technique is used in Scikit Learn Library

# %% [markdown]
# ![Screenshot%20%28316%29.png](attachment:Screenshot%20%28316%29.png)

# %% [markdown]
# # Basic Formulas To Calculate m and b are as follows

# %% [markdown]
# ![Screenshot%20%28321%29.png](attachment:Screenshot%20%28321%29.png)

# %% [markdown]
# # OLS is used in Two dimensions Only , for Higher Dimension Gradient Descent is Used

# %% [markdown]
# ![Screenshot%20%28322%29.png](attachment:Screenshot%20%28322%29.png)

# %% [markdown]
# # Above Figure shows how OLS or Gradient Descent work in to find Perfect Line over Data

# %% [markdown]
# # Conclude
