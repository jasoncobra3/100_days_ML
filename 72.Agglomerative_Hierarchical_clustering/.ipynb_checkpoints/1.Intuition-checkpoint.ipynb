# %% [markdown]
# # Different types of Clustering

# %% [markdown]
# ![Screenshot (542).png](attachment:b203fa97-a723-4c8a-a13f-69d182cb90cf.png)

# %% [markdown]
# ![WhatsApp Image 2024-03-14 at 5.13.39 PM.jpeg](attachment:af1e8d9b-05af-484c-8011-bf28055d00f9.jpeg)

# %% [markdown]
# ![WhatsApp Image 2024-03-14 at 5.13.40 PM.jpeg](attachment:5fdb7dab-0c00-43fa-bf47-be270cd02266.jpeg)

# %% [markdown]
# # 1.Single Link Clustering

# %% [markdown]
# ![Screenshot (543).png](attachment:ac307e1c-8216-43cb-b724-b0f016ad3b6b.png)

# %% [markdown]
# # 2.Complete link Clustering

# %% [markdown]
# ![Screenshot (544).png](attachment:8f2d1945-664c-4c74-9329-d6f948601e56.png)

# %% [markdown]
# ![Screenshot (545).png](attachment:ef464236-feba-4c51-aec4-25feb9f767de.png)

# %% [markdown]
# # How to find Ideal Number of Clusters..?

# %% [markdown]
# ## -> Using Dendogram

# %% [markdown]
# ### In dendogram look for the longest vertical line , which is not cut by any horizontal line.

# %% [markdown]
# ![Screenshot (546).png](attachment:252db623-14b5-410d-a0c7-e9c2a1721fb8.png)

# %% [markdown]
# ### In above dendogram you can see that topmost blue vertical line is not cut by any horizontal line , hence cluster by cutting this blue vertical line<br> Such that from above dendogram we can say that it has 2 clusters.

# %% [markdown]
# ![Screenshot (547).png](attachment:68d9176b-1e04-4377-97b1-442ce0a83fb1.png)

# %% [markdown]
# ### Similary for above dendogram there will be 5 clusters total.

# %% [markdown]
# # Benefits

# %% [markdown]
# - Widely Applicable
# - Dendogram

# %% [markdown]
# # Limitations

# %% [markdown]
# ## Not suitable for huge data

# %% [markdown]
# # Conclude
