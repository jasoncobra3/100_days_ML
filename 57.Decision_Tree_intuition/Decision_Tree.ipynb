# %% [markdown]
# ![WhatsApp%20Image%202024-02-15%20at%205.59.02%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-15%20at%205.59.02%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-15%20at%205.56.21%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-15%20at%205.56.21%20PM.jpeg)

# %% [markdown]
# ![Screenshot%20%28436%29.png](attachment:Screenshot%20%28436%29.png)

# %% [markdown]
# ![Screenshot%20%28437%29-2.png](attachment:Screenshot%20%28437%29-2.png)

# %% [markdown]
# ![Screenshot%20%28438%29.png](attachment:Screenshot%20%28438%29.png)

# %% [markdown]
# ![Screenshot%20%28441%29.png](attachment:Screenshot%20%28441%29.png)

# %% [markdown]
# ![Screenshot%20%28442%29.png](attachment:Screenshot%20%28442%29.png)

# %% [markdown]
# # Some Unanswered Question.

# %% [markdown]
# ![Screenshot%20%28443%29.png](attachment:Screenshot%20%28443%29.png)

# %% [markdown]
# ![Screenshot%20%28444%29.png](attachment:Screenshot%20%28444%29.png)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-15%20at%205.56.22%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-15%20at%205.56.22%20PM.jpeg)
