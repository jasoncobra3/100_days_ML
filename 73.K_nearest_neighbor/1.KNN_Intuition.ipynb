# %% [markdown]
# # Basic Working Principle of K Nearest neighbor is as follow:

# %% [markdown]
# ![download.jfif](attachment:71c9575b-24d4-48f1-a2fa-c5ba710584a4.jfif)

# %% [markdown]
# # Theory Intuition

# %% [markdown]
# ![WhatsApp Image 2024-03-15 at 11.24.36 PM.jpeg](attachment:844a2191-64b7-48b2-a9d3-cf901751d526.jpeg)

# %% [markdown]
# ![WhatsApp Image 2024-03-15 at 11.24.36 PM (1).jpeg](attachment:cde1c831-c3cc-42cb-925c-93d4ffbd0926.jpeg)

# %% [markdown]
# # Conclude
