# %% [markdown]
# # Softmax (Multinomial) Logistic Regression

# %% [markdown]
# ![WhatsApp%20Image%202024-02-14%20at%207.40.02%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-14%20at%207.40.02%20PM.jpeg)

# %% [markdown]
# # Training Intuition

# %% [markdown]
# ![WhatsApp%20Image%202024-02-14%20at%207.40.02%20PM%20%281%29.jpeg](attachment:WhatsApp%20Image%202024-02-14%20at%207.40.02%20PM%20%281%29.jpeg)

# %% [markdown]
# # Prediction

# %% [markdown]
# ![WhatsApp%20Image%202024-02-14%20at%207.40.03%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-14%20at%207.40.03%20PM.jpeg)

# %% [markdown]
# # Loss Function

# %% [markdown]
# ![WhatsApp%20Image%202024-02-14%20at%207.40.04%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-14%20at%207.40.04%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-14%20at%207.40.05%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-14%20at%207.40.05%20PM.jpeg)

# %% [markdown]
# # Conclude
