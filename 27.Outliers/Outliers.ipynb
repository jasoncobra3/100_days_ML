# %% [markdown]
# ### What is Outliers..?<br>The Data Poin that behaves differently than others  and can cause affect on distribution and Ml Models due to his behaviour

# %% [markdown]
# ### Ouliers are ALways Not Dangerous Sometimes They are useful also For. eg In Email Spam Detection , Spam Message Detection , and Many anomaly Detection Technique Outliers plays important Role

# %% [markdown]
# ### SO As a data scientist One shiould well known about the how to deal with outliers and traet them . Whether Outliers need to be deleted , Adjusted Or Replace

# %% [markdown]
# ### 1.Linera Regression <br> 2.Logistic Regression <br> 3.Adaboost <br> 4. Deep Learning <br> In the aBove All Tecniques Outliers Affect the Predicting ML Algorithm

# %% [markdown]
# ### How to Treat A Outliers..? <br> A]Trimming(This is Fast techniques but it reduces the Size of data )<br> B] Capping<br> C]Missing Value Treatment <br> D] Discritization

# %% [markdown]
# # How To Detect Outliers..?<br>1.Normal Distribution

# %% [markdown]
# ![Screenshot%20%28257%29.png](attachment:Screenshot%20%28257%29.png)##

# %% [markdown]
# # 2.Skewed Distribution

# %% [markdown]
# ![Screenshot%20%28260%29.png](attachment:Screenshot%20%28260%29.png)

# %% [markdown]
# # 3.Other Distribution

# %% [markdown]
# ![Screenshot%20%28261%29.png](attachment:Screenshot%20%28261%29.png)

# %% [markdown]
# # Techniques for Ouliers Detection and Removal

# %% [markdown]
# ![Screenshot%20%28262%29.png](attachment:Screenshot%20%28262%29.png)

# %% [markdown]
# # 1.Z score Tretment <br> 2.IQR based Filtering <br> 3.Percentile <br> 4.Winsorization

# %% [markdown]
# # Conclude
