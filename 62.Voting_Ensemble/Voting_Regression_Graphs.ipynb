# %% [markdown]
# # Voting Regression

# %% [markdown]
# # Data

# %% [markdown]
# ![Screenshot%20%28487%29.png](attachment:Screenshot%20%28487%29.png)

# %% [markdown]
# ## 1.Applyig only one Estimator as linear regression , unable to get the required accuracy with only one Estimator

# %% [markdown]
# ![Screenshot%20%28488%29.png](attachment:Screenshot%20%28488%29.png)

# %% [markdown]
# ## 2.Appplying two estimators as Linear rgression and SVR you can see that, accuracy of Voting_regressor increases as we use more than one estimator for prediction

# %% [markdown]
# ![Screenshot%20%28489%29.png](attachment:Screenshot%20%28489%29.png)

# %% [markdown]
# ## 3.As you know decison tree regressor overfits , you can see that voting regressor lines tries to lies in between the line of Linear regression and SVR and Decision tree regressor

# %% [markdown]
# ![Screenshot%20%28490%29.png](attachment:Screenshot%20%28490%29.png)

# %% [markdown]
# # Conclude
