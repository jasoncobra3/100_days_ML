# %% [markdown]
# # Voting Ensemble Classification

# %% [markdown]
# # Data

# %% [markdown]
# ![Screenshot%20%28479%29.png](attachment:Screenshot%20%28479%29.png)

# %% [markdown]
# # 1. when we uses only one Estimator for Prediction.

# %% [markdown]
# ![Screenshot%20%28476%29.png](attachment:Screenshot%20%28476%29.png)

# %% [markdown]
# ### You can see from the above is is work as the normal logistic regression

# %% [markdown]
# ![Screenshot%20%28478%29.png](attachment:Screenshot%20%28478%29.png)

# %% [markdown]
# # 2.When We use more than one Estimator for prediction

# %% [markdown]
# ![Screenshot%20%28480%29.png](attachment:Screenshot%20%28480%29.png)

# %% [markdown]
# ![Screenshot%20%28481%29.png](attachment:Screenshot%20%28481%29.png)

# %% [markdown]
# ## From above you can see that ,it gives the combination of two as the output , when we use more than one estimator.<br>Also it is more accuarate , as you can see the curve trace by voting classifier is more smooth and dividing the point more accurately.

# %% [markdown]
# ![Screenshot%20%28482%29.png](attachment:Screenshot%20%28482%29.png)

# %% [markdown]
# ![Screenshot%20%28483%29.png](attachment:Screenshot%20%28483%29.png)

# %% [markdown]
# ## In case of only one estimator it will classify the point by straight line , while in case of using multiple estimator it will cut point more smoothly and accuractely . Also Follows the curve.

# %% [markdown]
# # <br>

# %% [markdown]
# # Hard voting V/S Soft voting

# %% [markdown]
# ![WhatsApp%20Image%202024-02-19%20at%203.10.47%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-19%20at%203.10.47%20PM.jpeg)

# %% [markdown]
# ## Soft Voting

# %% [markdown]
# ![Screenshot%20%28484%29.png](attachment:Screenshot%20%28484%29.png)

# %% [markdown]
# ![Screenshot%20%28486%29.png](attachment:Screenshot%20%28486%29.png)

# %% [markdown]
# # Hard Voting

# %% [markdown]
# ![Screenshot%20%28485%29.png](attachment:Screenshot%20%28485%29.png)

# %% [markdown]
# # <br>

# %% [markdown]
# # Generally , soft voting will give the more accurate result than hard voting. Again it is parameter you can tune it to achieve more accuracy in different cases.

# %% [markdown]
# # Conclude
