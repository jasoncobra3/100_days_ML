# %% [markdown]
# # Why Lasso Regression Creates Sparsity...?

# %% [markdown]
# ## In Lasso Regression Alpha(lambda) is added at the side of Numerator that's why its create sparsity by making numerator zero , while in case of Ridge Regression alpha(lambda) is added on the Denominator Side , So it will never creates sparsity , but can make coefficient value close to the zero.

# %% [markdown]
# # Formula For Lasso Regression👇🏿👇🏿

# %% [markdown]
# ![WhatsApp%20Image%202024-02-05%20at%202.56.57%20AM.jpeg](attachment:WhatsApp%20Image%202024-02-05%20at%202.56.57%20AM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-05%20at%202.56.57%20AM%20%281%29.jpeg](attachment:WhatsApp%20Image%202024-02-05%20at%202.56.57%20AM%20%281%29.jpeg)

# %% [markdown]
# # <hr>

# %% [markdown]
# # Conclude
