# %% [markdown]
# ![WhatsApp Image 2024-03-24 at 8.16.43 PM.jpeg](attachment:833edd1e-8288-44e7-88ca-9d5f09ad396e.jpeg)

# %% [markdown]
# ![WhatsApp Image 2024-03-24 at 8.16.44 PM.jpeg](attachment:a6b1c204-6461-4095-8bdd-1217fc90d50d.jpeg)

# %% [markdown]
# # Conclude
