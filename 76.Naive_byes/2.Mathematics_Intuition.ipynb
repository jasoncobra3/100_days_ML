# %% [markdown]
# # Intuition

# %% [markdown]
# ![WhatsApp Image 2024-03-24 at 8.16.44 PM (1).jpeg](attachment:98117fe8-8957-461c-8ce7-e32f4cf06d7f.jpeg)

# %% [markdown]
# # Mathematics

# %% [markdown]
# ![WhatsApp Image 2024-03-24 at 8.16.44 PM (2).jpeg](attachment:ada60e60-720f-4ad7-b59b-833c6aaf52f0.jpeg)

# %% [markdown]
# # Formula

# %% [markdown]
# ![WhatsApp Image 2024-03-24 at 8.16.45 PM.jpeg](attachment:46e9a83d-60ad-4931-9ede-a0bcb5430c3f.jpeg)

# %% [markdown]
# # Conclude
