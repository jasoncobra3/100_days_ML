# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

# %%
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_squared_error , r2_score ,mean_absolute_error

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)
#Creating our own dataset using Make_Regression class of sklearn.datsets

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0 -0.099882  0.241783  -21.506297
# 1 -0.848491 -1.576630  -66.922250
# 2  0.611794  1.608346  149.196598
# 3  0.426113 -1.415673  -53.707914
# 4  1.234558  0.953437   44.274670

# %%
df.shape
# Out:
# (100, 3)

# %%
fig=px.scatter_3d(df,x='feature1',y='feature2',z='target')

# %%
fig #plotliy.express is used to plot 3d graph plots
# Out:
# <div>                            <div id="91161c2b-7671-421b-a662-1cd90041aa6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91161c2b-7671-421b-a662-1cd90041aa6d")) {                    Plotly.newPlot(                        "91161c2b-7671-421b-a662-1cd90041aa6d",                        [{"hovertemplate":"feature1=%{x}<br>feature2=%{y}<br>target=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.09988164795402629,-0.8484913160640962,0.6117943493150012,0.4261125068036766,1.234557569977732,-0.5718239483304078,-1.0158337997584899,0.7299915407429461,-0.902951016221475,1.687368514841318,-1.5132231715023756,0.06051259666241594,1.6351951054344764,-1.0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test)

# %%
print("MAE:",mean_absolute_error(Y_test,Y_pred))
print("MSE:",mean_squared_error(Y_test,Y_pred))
print("R2_score:",r2_score(Y_test,Y_pred))
# Out:
# MAE: 41.534887202429246
# MSE: 3207.374428060113
# R2_score: 0.303351365701391

# %%
#ignore this code no need to understand the below code , only focus ob Geometric intuition of concept
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T

z_final = lr.predict(final).reshape(10,10)

z = z_final

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
# Out:
# <div>                            <div id="7d546493-4ccd-4813-b070-3e3cd313a0d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d546493-4ccd-4813-b070-3e3cd313a0d8")) {                    Plotly.newPlot(                        "7d546493-4ccd-4813-b070-3e3cd313a0d8",                        [{"hovertemplate":"feature1=%{x}<br>feature2=%{y}<br>target=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.09988164795402629,-0.8484913160640962,0.6117943493150012,0.4261125068036766,1.234557569977732,-0.5718239483304078,-1.0158337997584899,0.7299915407429461,-0.902951016221475,1.687368514841318,-1.5132231715023756,0.06051259666241594,1.6351951054344764,-1.0
# ...

# %% [markdown]
# ## You can see that from the above graph, hyperplane is cutting most of the data points in the 3D space

# %%
lr.coef_
#for 2D data there will be 2 coefficient and hence coeeficient will increases with N dimension
# Out:
# array([36.35556059, 15.77988604])

# %%
lr.intercept_
#B0 (Beta zero will always be 1 for any dimension)
# Out:
# -3.119602313665818

# %% [markdown]
# # conclude
