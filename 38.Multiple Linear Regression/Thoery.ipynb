# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# # Just Like Simple Linear Regression , in this type reggression algorith find Linear Nature of Data , only difference is that it deal with N number of dimensions and plot  <ins>Hyperplane</ins> in the N dimensions covering to cut maximum points in the dimension

# %% [markdown]
# # Formula

# %% [markdown]
# ## for 2D

# %% [markdown]
# ![Screenshot%20%28346%29.png](attachment:Screenshot%20%28346%29.png)

# %% [markdown]
# ## for 3D (Considering Placement Dataset)

# %% [markdown]
# ![Screenshot%20%28349%29.png](attachment:Screenshot%20%28349%29.png)

# %% [markdown]
# # For N dimensions

# %% [markdown]
# ![Screenshot%20%28348%29.png](attachment:Screenshot%20%28348%29.png)

# %% [markdown]
# ### If there are 2 input columns then there will be 2 coefficient <br> Such that For N column there will be N Coefficient(m)

# %% [markdown]
# ### B0 (beta 0) is Intercept of line

# %% [markdown]
# ### There will be always hyperplane for n dimension data

# %% [markdown]
# # Conclude
