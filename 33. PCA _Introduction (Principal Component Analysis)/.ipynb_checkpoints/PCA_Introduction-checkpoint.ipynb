# %% [markdown]
# # Principal Component   Analysis

# %% [markdown]
# # 1.Introduction

# %% [markdown]
# ### Eg .  A photographer Captures A Soccer Ground Image , which means he is capturing or converting in 3d object to 2D object in his photograph , <br>Above Example Is nothing But One f the exaple of PCA as it is reducing the higher dimension data to lower dimension <br>While Capturing the image of soccer field Photographer captures photo from the different angles in playground such that he will get the best shot which covers or include all players on the soccerr ground in the photo , this is called Principal Component Analysis, wherewe find the best angle to reduce our high dimensional data to lower dimensions such that it will cover alll point which are present in higher dimension data.

# %% [markdown]
# # 2.Benefits Of PCA

# %% [markdown]
# ## 1.Execution Of Algorithm Become Faster as We reduce the Dimension of the Data <br> 2.Visualization of data become easy.

# %% [markdown]
# # 3. Geometric Intuition

# %% [markdown]
# ### first we perform Feature Selection to extract Feature from the given Data<br> Feature selection can be done as

# %% [markdown]
# ![Screenshot%20%28291%29.png](attachment:Screenshot%20%28291%29.png)

# %% [markdown]
# ## We Project the Given Data Points in the respective Axes , if data is higher dimnsional , then it will project on the all axes<br>from the above graph you can see that data point are project on the both axes <br> after Projection of Data Point we check for the spread of data Across Axes the axis which is having higher spread is get selected <br> in the above axis you can see that X-axis have higher spread such that it will get selected

# %% [markdown]
# ### Case 2

# %% [markdown]
# ![Screenshot%20%28292%29.png](attachment:Screenshot%20%28292%29.png)

# %% [markdown]
# ## Sometimes As a data scientist we dealing with some kinds of data where spred of data across Axes is Same , in such situation it may get confusing which column(axes) should get selected <br> In the above example you can see that Room no. and Washroom decide the overall price of the house this situation might seem confusing , but with help PCA , we can convert both columns into one single column name as Size <br> We move Any one axes in such way that , projection of data on anyone axis is greater compare to other & then we will select that column

# %% [markdown]
# # 4.Why Variance Is Important..?

# %% [markdown]
# ### Variance is not Actual spread of data  , But It is Somewhat proportional to Spread of the Data

# %% [markdown]
# # Spread is Proportion to Variance

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# # ***IT Is Important to note that***

# %% [markdown]
# ## When you are moving data from higher dimension to lower dimension in such case , the distance between data point may not be change such that will arises difficulty in algorithms

# %% [markdown]
# ### Such that Relationship between Data Point does not get disturb , to maintain relationship between data points while moving data from higher dimension to lower dimension , We are  MAXIMIZING THE VARIANCE

# %% [markdown]
# ### SO that's Why Variance is so Important , while performing PCA , our end goal is to maximize VARIANCE

# %% [markdown]
# ![Screenshot%20%28293%29.png](attachment:Screenshot%20%28293%29.png)

# %% [markdown]
# ## For Example⏫⏫

# %% [markdown]
# ## To Be Continue...
