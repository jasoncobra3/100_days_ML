# %% [markdown]
# ![WhatsApp%20Image%202024-02-18%20at%207.57.31%20PM.jpeg](attachment:WhatsApp%20Image%202024-02-18%20at%207.57.31%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-18%20at%207.57.31%20PM%20%281%29.jpeg](attachment:WhatsApp%20Image%202024-02-18%20at%207.57.31%20PM%20%281%29.jpeg)

# %% [markdown]
# # Why it Works...?

# %% [markdown]
# ## 1.For Classification problem

# %% [markdown]
# ![Screenshot%20%28473%29.png](attachment:Screenshot%20%28473%29.png)

# %% [markdown]
# ![Screenshot%20%28474%29.png](attachment:Screenshot%20%28474%29.png)

# %% [markdown]
# ## 2.For Regression Problems.

# %% [markdown]
# ![Screenshot%20%28475%29.png](attachment:Screenshot%20%28475%29.png)

# %% [markdown]
# # *When to use Ensemble Learning...?

# %% [markdown]
# # -> Always😎

# %% [markdown]
# # <br>

# %% [markdown]
# # Conclude
