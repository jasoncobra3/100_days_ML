# %% [markdown]
# ### Parameters
# class sklearn.ensemble.RandomForestClassifier(n_estimators=100, *, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None, monotonic_cst=None)

# %% [markdown]
# ### 1. n_estimators= 100 <br> Default value is 100 while it is used to decide the number of base models (Decision trees) for calculation

# %% [markdown]
# ### 2.max_features=n <br> The number of features to consider when looking for the best split<br>This parameter is used to decide the number of columns for splitting criteria.<br>
# If “sqrt”, then max_features=sqrt(n_features).<br>
# If “log2”, then max_features=log2(n_features).<br>
# If None, then max_features=n_features.

# %% [markdown]
# ### 3.bootstrap=True<br>this Parameter decide whether we are randomly selecting rows and columns for sampling.

# %% [markdown]
# ### 4.max_samples=None<br> Decides the number of rows we are passing to decision tree

# %% [markdown]
# ### 5.n_jobs=None<br>Help to train decision trees parallely.<br> Such that one can use multipe cores for training the model if its machine exist a multiple cores.

# %% [markdown]
# ### 6.random_state=None<br>Use for uniformity

# %% [markdown]
# ### 7.verbose=0 <br> Gives all output during training

# %% [markdown]
# ### 8.Warm_start=False<br>we used this parameter to train algorithm in Stages

# %% [markdown]
# ### 9. class_weight=None<br>used it when we have a imbalanced dataset

# %% [markdown]
# # <hr>

# %% [markdown]
# # Data

# %% [markdown]
# ![Screenshot%20%28518%29.png](attachment:Screenshot%20%28518%29.png)

# %% [markdown]
# # Hyperparameter tuning to gain Maximum Accuracy

# %% [markdown]
# ![Screenshot%20%28519%29.png](attachment:Screenshot%20%28519%29.png)

# %% [markdown]
# ![Screenshot%20%28520%29.png](attachment:Screenshot%20%28520%29.png)

# %% [markdown]
# ![Screenshot%20%28521%29.png](attachment:Screenshot%20%28521%29.png)

# %% [markdown]
# # From Above Pictures you can see that accuracy of Model increases as we increase the number of estimators in the model.
# <hr>

# %% [markdown]
# ![Screenshot%20%28523%29.png](attachment:Screenshot%20%28523%29.png)

# %% [markdown]
# ![Screenshot%20%28524%29.png](attachment:Screenshot%20%28524%29.png)

# %% [markdown]
# ![Screenshot%20%28525%29.png](attachment:Screenshot%20%28525%29.png)

# %% [markdown]
# # As we Decrease the number of max samples , Accuracy for Random Forest is increasing.<hr>

# %% [markdown]
# # Note: As we decrease the max sample Randomness in data increases<hr>

# %% [markdown]
# (Parameters for Randomforest_Classifier and RandomForest_Regressor is Same there is only minute changes , for further reference you can use official documentation of Random Forest)
# # Conclude
