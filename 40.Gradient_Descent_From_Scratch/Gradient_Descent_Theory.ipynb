# %% [markdown]
# # Gradient Descent

# %% [markdown]
# ## Gradient descent is a method for unconstrained mathematical optimization. It is a first-order iterative algorithm for finding a local minimum of a differentiable multivariate function<br> <br>The idea is to take repeated steps in the opposite direction of the gradient (or approximate gradient) of the function at the current point, because this is the direction of steepest descent.

# %% [markdown]
# # It is Backbone Of Deep Learning

# %% [markdown]
# # *Intuition

# %% [markdown]
# ### Step 1:-Select Random value of b

# %% [markdown]
# ![Screenshot%20%28354%29.png](attachment:Screenshot%20%28354%29.png)

# %% [markdown]
# #### The Goal Is to Find the minimum value for Loss Function

# %% [markdown]
# ### We need to increment or Decrement B to Find The Best Optimal Solution

# %% [markdown]
# ### To Move The B we find Slope at that point and on the Basis of that Value We move the Point (increment or Decrement)

# %% [markdown]
# # We use following Formula

# %% [markdown]
# ![Screenshot%20%28353%29.png](attachment:Screenshot%20%28353%29.png)

# %% [markdown]
# ## Modified Formula

# %% [markdown]
# ![Screenshot%20%28355%29.png](attachment:Screenshot%20%28355%29.png)

# %% [markdown]
# ## Where n is Learning Factor <br> Learning Factor = 0.01

# %% [markdown]
# ## we use learning Factor to Move b slowly , if we dont use Learnning Factor in Formula we will move directly to other side and it will jump and might create a incorrect result , if we don't use learning factor it will craete a zig-zag pattern

# %% [markdown]
# ## Learning Factor Neither be to large nor to Small

# %% [markdown]
# ## *When To Stop  b to move

# %% [markdown]
# ## when b(old)-slope=close to zero then we need to stop to find B(new)

# %% [markdown]
# # You can Manually set Epox to find b(new)

# %% [markdown]
# # <ins>Mathematical Formulation</ins>

# %% [markdown]
# ![WhatsApp%20Image%202024-01-22%20at%2012.17.01%20AM.jpeg](attachment:WhatsApp%20Image%202024-01-22%20at%2012.17.01%20AM.jpeg)

# %% [markdown]
# # Conclude
