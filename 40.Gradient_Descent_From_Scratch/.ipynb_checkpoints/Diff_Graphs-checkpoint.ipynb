# %% [markdown]
# # Graphs

# %% [markdown]
# ![animation.gif](attachment:animation.gif)#

# %% [markdown]
# # The Above Graph Shows How Gradient Descent Converge Towards a Solution

# %% [markdown]
# # 2.Graph 2

# %% [markdown]
# ## The Below Graph is Draw as Cost() Vs b(intercept)

# %% [markdown]
# ### Where cost is

# %% [markdown]
# ![Screenshot%20%28369%29.png](attachment:Screenshot%20%28369%29.png)

# %% [markdown]
# ![animation3.gif](attachment:animation3.gif)

# %% [markdown]
# # Graph 3

# %% [markdown]
# ## The Below Graph is of Cost() VS Epochs

# %% [markdown]
# ![animation1.gif](attachment:animation1.gif)

# %% [markdown]
# ### the above Graph Shows where to Stop

# %% [markdown]
# # Graph 4

# %% [markdown]
# ## The Below Graph shows  b(intercept) VS m(Slope) <br> such that b becomes constant even if the value of m increases

# %% [markdown]
# ![animation2.gif](attachment:animation2.gif)

# %% [markdown]
# <span style="color:blue"><hr> </span>.

# %% [markdown]
# # 1. Effect of Learning Rate

# %% [markdown]
# ![Screenshot%20%28361%29.png](attachment:Screenshot%20%28361%29.png)

# %% [markdown]
# ## In the Above Graph:-<br> 1.The 1st graph shows what happend when Learning rate is Too Small <br> 2.The 2nd Graph shows when learning rate is optimum we can reach to the solution <br> 3. The 3rd graph shows when learning rate is too large it will jump to some large values and miss the solution

# %% [markdown]
# # <hr>

# %% [markdown]
# ## Mixing m into Equation

# %% [markdown]
# ![Screenshot%20%28362%29.png](attachment:Screenshot%20%28362%29.png)

# %% [markdown]
# ## We Can Simultaneously find the m and b for formula

# %% [markdown]
# # Effect Of Loss Function

# %% [markdown]
# ## Convex Function

# %% [markdown]
# ![Screenshot%20%28370%29.png](attachment:Screenshot%20%28370%29.png)

# %% [markdown]
# ### If We draw a line between this then finction will not cross the line, we have only one minima which is global minima

# %% [markdown]
# # Non-convex Funtion

# %% [markdown]
# ![Screenshot%20%28363%29.png](attachment:Screenshot%20%28363%29.png)

# %% [markdown]
# ### In the above fuunction has a 2 minima a local minima and global minima, sometimes we get stuck in local minima and can't identify the the global minima

# %% [markdown]
# ## Intial Value matters for Non-convex function

# %% [markdown]
# # There is high possibility you will start from  wrong intial state and stuck in  local minima and there is no chance to escape , that is harsh reality

# %% [markdown]
# # Convex Function in  3d

# %% [markdown]
# ![Screenshot%20%28371%29.png](attachment:Screenshot%20%28371%29.png)

# %% [markdown]
# # <ins>Non-convex Function</ins> in 3d

# %% [markdown]
# ![Screenshot%20%28365%29.png](attachment:Screenshot%20%28365%29.png)

# %% [markdown]
# # ***Saddle Point Problem***

# %% [markdown]
# ## This Problem arise due to flat Surfaces(plateu) as surface is flat slope will change slowly and takes minimum stapes and it will take a long time to reach actuall solution and alos needs large number of epochs and calculation times , which is not good for algorithm (this is known as saddle point)

# %% [markdown]
# ### saddle-point in 3d

# %% [markdown]
# ![Screenshot%20%28366%29.png](attachment:Screenshot%20%28366%29.png)

# %% [markdown]
# ## It will take a lot of time to move from this flat surface

# %% [markdown]
# # ***Effect Of Data***

# %% [markdown]
# ![Screenshot%20%28367%29.png](attachment:Screenshot%20%28367%29.png)

# %% [markdown]
# # 1.You can see if data have feature with equal scalling , contour plot will be circular and it will move fastly from one point to anpther point <br>2.If feature Scalling is far different it will take a lot of time to converge

# %% [markdown]
# ## That's Why Scalling of Data is Important before feeding to any ML model

# %% [markdown]
# # Conclude
