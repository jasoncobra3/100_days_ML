# %% [markdown]
# ![WhatsApp%20Image%202024-02-17%20at%2011.36.27%20AM.jpeg](attachment:WhatsApp%20Image%202024-02-17%20at%2011.36.27%20AM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202024-02-17%20at%2011.36.27%20AM%20%281%29.jpeg](attachment:WhatsApp%20Image%202024-02-17%20at%2011.36.27%20AM%20%281%29.jpeg)

# %% [markdown]
# ## Just Like Decision Tree Classifier , Regression tree has the same hyperparameters only difference is that criterion in Regression tree is <br>criterion{“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error” for[Regression Tree]<br> Instead of  criterion in Decision tree classifier is<br> criterion{“gini”, “entropy”, “log_loss”}, default=”gini” [for decision tree classifier]

# %% [markdown]
# # Conclude
