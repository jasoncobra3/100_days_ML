# %% [markdown]
# # <ins> Regression Metrics</ins>

# %% [markdown]
# # 1.MAE(Mean Absilute Error)<br>2.MSE(Mean Squared Error)<br>3.RMSE(Root Mean Squared Error)<br>4.R2_Score<br>5.Adjusted R2_score

# %% [markdown]
# # <ins>1.MAE(Mean Absolute Error)</ins>

# %% [markdown]
# ## Formula

# %% [markdown]
# ![Screenshot%20%28328%29.png](attachment:Screenshot%20%28328%29.png)

# %% [markdown]
# ### Advantages:<br>1.Gives the Same Unit in Output <br> 2.Robust To outliers

# %% [markdown]
# ### Disadvantages:<br>Graph is not Differentiable at 0

# %% [markdown]
# # <ins>2.MSE(Mean Squared Error)</ins>

# %% [markdown]
# ### Formula

# %% [markdown]
# ![Screenshot%20%28333%29.png](attachment:Screenshot%20%28333%29.png)

# %% [markdown]
# #### It Creates A square on Best fit Line And find the overall minimum sum of squares`

# %% [markdown]
# ### Graph

# %% [markdown]
# ![Screenshot%20%28334%29.png](attachment:Screenshot%20%28334%29.png)

# %% [markdown]
# ### Advantages:<br>It can be Use As Loss Function <br>Graph is Differentiable At 0

# %% [markdown]
# ### Disadvantages:<br>It cannot Robust To Outliers

# %% [markdown]
# # <ins>3.Root Mean Squared Error(RMSE)</ins>

# %% [markdown]
# ### Formula

# %% [markdown]
# ![Screenshot%20%28335%29.png](attachment:Screenshot%20%28335%29.png)

# %% [markdown]
# ## Advantages:It is Differentiable At 0 & Gives output in same unit

# %% [markdown]
# ## Disadvantages:It is not Robust to Outliers

# %% [markdown]
# # <ins>4.R2_Score</ins>

# %% [markdown]
# ## It is also Called as Coefficient Of Determination and Goodness Of Fit

# %% [markdown]
# ### R2_Score works with Mean Fit line and Regression Line

# %% [markdown]
# ## In Below Graph Red Line is Mean Fit line and Blue Line is Rgression Line for the data

# %% [markdown]
# ![Screenshot%20%28336%29.png](attachment:Screenshot%20%28336%29.png)

# %% [markdown]
# # Formula

# %% [markdown]
# ![Screenshot%20%28337%29.png](attachment:Screenshot%20%28337%29.png)

# %% [markdown]
# ## where SSR=Sum of Squared Error in the Regression Line <br> SSM=Sum of Squared Error in Mean Line

# %% [markdown]
# ![Screenshot%20%28338%29.png](attachment:Screenshot%20%28338%29.png)

# %% [markdown]
# # Two Conditions Arises:<br> 1.R2=0 , Means Answer is not correct towards incorrectness(When Regression Line falls on Mean Line R2=0)<br>2.R2=1 , means Answers is correct and tends towards correctness(When All the points in Data Falls on Regression Line R2=1)

# %% [markdown]
# # R2=-ve , when not a single Data is fall on Regression line such that line drawn differently from mean line(SSR>SSM)

# %% [markdown]
# ### In this Regression metrics , near the value of 1 means more accurate result while near to 0 means less accurate

# %% [markdown]
# ## If R2_score=0.80 that means it represent 80% of data variance(eg. CGPA explain 80% of variance of Palcement)

# %% [markdown]
# # Advantages:It is unit Independent such that it can apply and used in most of Algorithm irrespective of type of data

# %% [markdown]
# ### Disadvantage:It can consider any random Input column during Matric Evolution such that it can affect Output of Metrics also rises the score of Metrics

# %% [markdown]
# # <ins>5.Adjusted R2_score</ins>

# %% [markdown]
# # Formula

# %% [markdown]
# ![Screenshot%20%28339%29.png](attachment:Screenshot%20%28339%29.png)

# %% [markdown]
# # where <br> R2=R2 score<br>n=no.of rows <br>k=independent

# %% [markdown]
# ## R2_adjusted_score is more reliable in Multiple Regression

# %% [markdown]
# # Advantages: It can Overcome the disadvantages of R2_score metrics

# %% [markdown]
# ### It is also unit independent Accuracy Metrics

# %% [markdown]
# # It can ignore the random input column irrelevant(not in relation with)of output also can consider the column which are useful for output column

# %% [markdown]
# # Conclude
