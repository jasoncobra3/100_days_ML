# %%
import pandas as pd
import numpy as np
import seaborn as sns
import requests
from bs4 import BeautifulSoup

# %%
url="https://www.coursera.org/courses?page=2&sortBy=BEST_MATCH"
webpage=requests.get(url).text

# %%
webpage
# Out:
# '<!DOCTYPE html><html xmlns:fb="http://ogp.me/ns/fb#" itemtype="http://schema.org" lang="en" dir="ltr"><head><link rel="preconnect" href="https://d3njjcbhbojbot.cloudfront.net" crossorigin><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7"><meta charset="utf-8"><meta property="og:site_name" content="Coursera"><meta property="fb:admins" content="727836538,4807654"><meta property="fb:app_id" content="823425307723964"><meta name="twitter:site" content="Coursera"><meta name="twitter:app:name:iphone" content="Coursera"><meta name="twitter:app:name:ipad" content="Coursera"><meta name="twitter:app:name:googleplay" content="Coursera"><meta name="twitter:app:id:iphone" content="id736535961"><meta name="twitter:app:id:ipad" content="id736535961"><meta name="twitter:app:id:googleplay" content="org.coursera.android"><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="apple-touch-icon" sizes="57x57" href="https://d3njjcbhbojbot.cloudfront.net/web/images/fav
# ...

# %%
soup=BeautifulSoup(webpage,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
course=soup.find_all('div',class_="cds-ProductCard-gridCard")

# %%
len(course)
# Out:
# 12

# %%
name=[]
company_name=[]
ratings=[]
info=[]
icons=[]
skills=[]
reviews=[]
for i in course:
    name.append(i.find("h3",class_="cds-119 cds-CommonCard-title css-e7lgfl cds-121").text.strip())
    company_name.append(i.find("p",class_="cds-119 cds-ProductCard-partnerNames css-dmxkm1 cds-121").text.strip())
    icons.append(i.find('img')['src'])
    ratings.append(i.find_all("p",class_="cds-119 css-11uuo4b cds-121")[0].text.strip())
    reviews.append(i.find_all("p",class_="cds-119 cds-Typography-base css-dmxkm1 cds-121")[1].text.strip())
    info.append(i.find("div",class_="cds-CommonCard-metadata").text.strip())
    skills.append(i.find_all("p",class_="cds-119 cds-Typography-base css-dmxkm1 cds-121")[0].text.strip())

# ratings_item = [float(item.split('(')[0]) for item in ratings]
# reviews = [str(item.split('(')[1]) for item in ratings]

# %%
temp=[]
for i in info:
    temp2=i.split("Â·")
    temp.append(temp2)

# %%
temp
level=[]
duration=[]
typ=[]
for i in temp:
    level.append(i[0])
    duration.append(i[2])
    typ.append(i[1])

# %%
icons
# Out:
# ['https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/32/d719a2d0d946d59e1151bc10ec29f5/Specialization-Certificate-Emblem---IDS---600x600.png?auto=format%2Ccompress%2C%20enhance&dpr=1&w=265&h=216&fit=crop&q=50',
#  'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/1b/67a18a33de439c974816ebfd42e7b2/unnamed.png?auto=format%2Ccompress%2C%20enhance&dpr=1&w=265&h=216&fit=crop&q=50',
#  'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/93/1543b8c7d64dad864ca79e876a065d/Key-Technology-Foundations-1-.png?auto=format%2Ccompress%2C%20enhance&dpr=1&w=265&h=216&fit=crop&q=50',
#  'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bd/0202c87e244d30bdecd889bd2719ae/DataScienceFundamentalsPythonSQL.png?auto=format%2Ccompress%2C%20enhance&dpr=1&w=265&h=216&fit=crop&q=50',
# ...

# %%
reviews
# Out:
# ['(86K reviews)',
#  '(47K reviews)',
#  '(82K reviews)',
#  '(60K reviews)',
#  '(30K reviews)',
#  '(142K reviews)',
#  '(46K reviews)',
#  '(49K reviews)',
#  '(2K reviews)',
#  '(37K reviews)',
#  '(78K reviews)',
#  '(20K reviews)']
