# %%
import pandas as pd
import numpy as np
import seaborn as sns
import requests
from bs4 import BeautifulSoup

# %%
url="https://internshala.com/internships/matching-preferences/page-2/"
# headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get(url,headers=headers).text

# %%
webpage
# Out:
# '<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml"\n      lang="en-US">\n\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=9" />\n    <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n    <meta property="fb:app_id" content="702141670710132" />\n    <meta property="og:type" content="website" />\n        <meta property="og:image:width" content="1200" />\n    <meta property="og:image:height" content="630" />\n    <link rel="preload" href="https://internshala.com//static/images/home/sprites/assets.png" as="image"/>\n<link rel="preload" as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r767.png" media="(max-width: 767px)"/>\n<link rel="preload" as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r1920.png" media="(min-width: 767.1px)"/>    <meta name="twi
# ...

# %%
soup=BeautifulSoup(webpage,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="702141670710132" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <link as="image" href="https://internshala.com//static/images/home/sprites/assets.png" rel="preload"/>
# <link as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r767.png" media="(max-width: 767px)" rel="preload"/>
# <link as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r1920.png" media="(min-width: 767.1px)" rel="preload"/> <meta content="@Internshala" name="twitter:site"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
#   <meta content="702141670710132" property="fb:app_id"/>
#   <meta content="website" property="og:type"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <link as="image" href="https://internshala.com//static/images/home/sprites/assets.png" rel="preload"/>
#   <link as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r767.png" media="(max-width: 767px)" rel="preload"/>
#   <link as="image" href="https://internshala.com//static/images/internship/banners/jobs_banner_r1920.png" media="(min-width: 767.1px)" rel="preload"/>
# ...

# %%
company=soup.find_all("div",class_= "internship_meta")

# %%
len(company)
# Out:
# 49

# %%
name=[]
company_name=[]
location_name=[]
working_mode=[]
start_date=[]
stipend=[]
sal=[]
duration=[]
for i in company:
    name.append(i.find("a",class_="view_detail_button").text.strip())
    company_name.append(i.find("div",class_="heading_6 company_name").text.strip())
#     location_name.append(i.find("span").text.strip())
    location_name.append(i.find("a",class_="location_link view_detail_button").text.strip())
    start_date.append(i.find("div",class_="success_and_early_applicant_wrapper").text.strip())
    stipend.append(i.find("div",class_="item_body salary").text.strip())
#     duration.append(i.find_all("div",class_="other_detail_item")[1].text.strip())
    
    

data=pd.DataFrame({
    "Job Name":name,
    "company_name":company_name,
    "location":location_name,
    "Job Post":start_date,
    "Salary":stipend
})

# %%
data
# Out:
#                                         Job Name  \
# 0                 Business Development Associate
# 1                                     Telecaller
# 2                      Corporate Sales Executive
# 3                       Junior Interior Designer
# 4                   Academic Associate - Finance
# 5                          Behavioural Therapist
# 6               Operations Manager (Procurement)
# 7              Junior Travel & Tourism Executive
# 8                                  SEO Executive
# 9                          Field Sales Executive
# 10                        Online English Faculty
# 11                        Inside Sales Executive
# 12  Executive - Content Operations (Contractual)
# 13        Trainee Engineer_Civil (only Freshers)
# 14                    Junior Mechanical Engineer
# 15                                  Video Editor
# 16                  Junior Recruitment Executive
# 17                              Junior Recruiter
# ...

# %%
len(company_name)
# Out:
# 49

# %%
company_name
# Out:
# ['Bizknowmics',
#  'Dare2Gear',
#  'Jatin Glass Company',
#  'G2Design Interior',
#  'Midha Education Private Limited',
#  'Leap Skills',
#  'BioFics Private Limited',
#  'Bulls Travelism Private Limited',
#  'Hiigher®',
#  'QuickSort Solutions',
#  'PlanetSpark',
#  'NoBroker Technologies Solutions Private Limited',
#  'Saregama India Limited',
#  'NoBroker Technologies Solutions Private Limited',
#  'ASMACS Skill Development Limited',
#  'ASMACS Skill Development Limited',
#  'ASMACS Skill Development Limited',
#  'ASMACS Skill Development Limited',
#  'ASMACS Skill Development Limited',
#  'ASMACS Skill Development Limited',
#  'ASMACS Skill Development Limited',
#  'NoBroker Technologies Solutions Private Limited',
#  'QuickSort Solutions',
#  'Saregama India Limited',
#  'ASMACS Skill Development Limited',
#  'QuickSort Solutions',
#  'Saregama India Limited',
#  'QuickSort Solutions',
#  'PlanetSpark',
#  'ASMACS Skill Development Limited',
#  'Media.net',
# ...

# %%
len(location_name)
# Out:
# 49

# %%
location_name
# Out:
# ['Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Delhi',
#  'Actively hiring',
#  'Pune',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Mumbai',
#  'Actively hiring',
#  'Actively hiring',
#  'Navi Mumbai',
#  'Actively hiring',
#  'Gurgaon',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Delhi',
#  'Actively hiring',
#  'Gurgaon',
#  'Actively hiring',
#  'Actively hiring',
#  'Gurgaon',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Actively hiring',
#  'Bangalore',
#  'Actively hiring',
# ...

# %%
data_frame=[]
for j in range(1,11):
    url="https://internshala.com/internships/matching-preferences/page-{}/".format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage=requests.get(url,headers=headers).text 
    soup=BeautifulSoup(webpage,"html.parser")
    company=soup.find_all("div",class_= "internship_meta")
    name=[]
    company_name=[]
    location_name=[]
    working_mode=[]
    start_date=[]
    stipend=[]
    sal=[]
    duration=[]
    for i in company:
        name.append(i.find("a",class_="view_detail_button").text.strip())
        company_name.append(i.find("div",class_="heading_6 company_name").text.strip())
    #     location_name.append(i.find("span").text.strip())
        location_name.append(i.find("a",class_="location_link view_detail_button").text.strip())
        start_date.append(i.find("div",class_="success_and_early_applicant_wrapper").text.strip())
        stipend.append(i.find("div",class_="item_body salary").text.strip())
    #     duration.append(i.find_all("div",class_="other_detail_item")[1].text.strip())
        
        
    
    data_f=pd.DataFrame({
        "Job Name":name,
        "company_name":company_name,
        "location":location_name,
        "Job Post":start_date,
        "Salary":stipend
    })
    data=pd.concat([data,data_f],ignore_index=True)

# %%
data
# Out:
#                            Job Name                      company_name  \
# 0    Business Development Associate                       Bizknowmics
# 1                        Telecaller                         Dare2Gear
# 2         Corporate Sales Executive               Jatin Glass Company
# 3          Junior Interior Designer                 G2Design Interior
# 4      Academic Associate - Finance   Midha Education Private Limited
# ..                              ...                               ...
# 534               Associate - Sales                         Media.net
# 535            Data Entry Associate  ASMACS Skill Development Limited
# 536       Corporate Sales Associate               QuickSort Solutions
# 537       Junior Software Developer  ASMACS Skill Development Limited
# 538               English Tutor-WFH                       PlanetSpark
#
#            location                               Job Post  \
# 0           Chennai                            3 weeks ago
# ...

# %%
data.shape
# Out:
# (539, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Job Name      539 non-null    object
#  1   company_name  539 non-null    object
#  2   location      539 non-null    object
#  3   Job Post      539 non-null    object
#  4   Salary        539 non-null    object
# dtypes: object(5)
# memory usage: 21.2+ KB

# %%
data.to_csv("Internship.csv")

# %%
pd.read_csv("Internship.csv")
# Out:
#      Unnamed: 0                        Job Name  \
# 0             0  Business Development Associate
# 1             1                      Telecaller
# 2             2       Corporate Sales Executive
# 3             3        Junior Interior Designer
# 4             4    Academic Associate - Finance
# ..          ...                             ...
# 534         534               Associate - Sales
# 535         535            Data Entry Associate
# 536         536       Corporate Sales Associate
# 537         537       Junior Software Developer
# 538         538               English Tutor-WFH
#
#                          company_name        location  \
# 0                         Bizknowmics         Chennai
# 1                           Dare2Gear           Noida
# 2                 Jatin Glass Company      Chandigarh
# 3                   G2Design Interior            Pune
# 4     Midha Education Private Limited          Ranchi
# ..                                ...             ...
# ...

# %% [markdown]
# ## Conclude
