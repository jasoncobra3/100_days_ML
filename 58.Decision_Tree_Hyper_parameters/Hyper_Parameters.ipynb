# %% [markdown]
# ## If Depth of Decison tree is not enough togrow , it will underfit <br> Similarly if depth of tree is too large to grow it will Overfit

# %% [markdown]
# # Overfitting

# %% [markdown]
# ![Screenshot%20%28468%29.png](attachment:Screenshot%20%28468%29.png)

# %% [markdown]
# ![Screenshot%20%28469%29.png](attachment:Screenshot%20%28469%29.png)

# %% [markdown]
# # Underfitting

# %% [markdown]
# ![Screenshot%20%28470%29.png](attachment:Screenshot%20%28470%29.png)

# %% [markdown]
# ![Screenshot%20%28471%29.png](attachment:Screenshot%20%28471%29.png)

# %% [markdown]
# # Hyper-Parameters

# %% [markdown]
# ## 1.Criterion=('gini','entropy')<br>gini for gini impurity and entropy for entropy<br> Generally gini gives better result than entropy

# %% [markdown]
# ## 2.Splitter=('random','best')<br>best chooses the best split<br> While Random used for random splitting such that it help to reduce overfitting<br> There are chances of overfitting while using best

# %% [markdown]
# ## 3.Max_depth=none<br>It can be any number eg,1,2,3....etc<br> Greater the number tree will overfit<br>Smaller the number tree will underfit

# %% [markdown]
# ## 4.min_samples_split=2<br>Its By default value is 2, but you can change it , It stops splitting when leaf node has lesser number of samples than min_sample.<br>Greater the min_sample higher chances of underfitting & lesser the min_sample ,higher chances of overfitting.

# %% [markdown]
# ## 5.min_samples_leaf=1<br>its by default value is 1 , but you can give any number base on data, it will stop growing tree just before the point it know, when the next node is not going to satisfy the condition<br>Greater the min_sample higher chances of underfitting & lesser the min_sample ,higher chances of overfitting.

# %% [markdown]
# ## 6.max_features=None<br>It is used decide the number of column to split the tree, its minimum value is 1 . <br>By default it use all columns or feature for splitting , but we can limit it by passing max_features parameter<br>We can use it when we ae working on higher dimensional data , to reduce overfitting on decision tree

# %% [markdown]
# ## 7.max_leaf_nodes=None<br>It control how many numbers of node we want to create on Decision tree<br>Higher value will lead to overfitting <br> Lower value will lead to underfitting

# %% [markdown]
# ## 8.min_impurity_decrease=0.0<br> Its use to split on the basis of impurity in node , we can give float value to min_impurity_decrease .<br>Higher the value it will underfit <br>Lower the valur it will overfit.

# %% [markdown]
# # Conclude
